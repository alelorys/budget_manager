# %%
import pandas as pd
import numpy as np
# Out:
# znajdzka {"date":"2025-08-02T09:38:07.798Z","msg_id":"b542ac6b-13d7-4202-a885-c65314e9c9d8","msg_type":"execute_request","session":"66273808-415b-458f-95e8-652902888b3d","username":"75958906-7f29-430b-b003-50b42a1f9d63","version":"5.2"}
# znajdzka {}
# znajdzka {"cellId":"vscode-notebook-cell:/c%3A/Users/aleks/Documents/programowanie/Python/AI/budget_manager/src/tracker/predict/work_file.ipynb#W1sZmlsZQ%3D%3D"}
# znajdzka {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":false,"code":"df = pd.read_csv(r'C:\\Users\\aleks\\Documents\\programowanie\\Python\\AI\\budget_manager\\src\\tracker\\predict\\budzet-2.csv', sep=';')"}

# %%
df = pd.read_csv(r'C:\Users\aleks\Documents\programowanie\Python\AI\budget_manager\src\tracker\predict\budzet-2.csv', sep=';')
# Out:
# znajdzka {"date":"2025-08-02T09:38:48.196Z","msg_id":"6e97a1ca-7828-4d3a-9d53-d3d6e98f2c2b","msg_type":"execute_request","session":"66273808-415b-458f-95e8-652902888b3d","username":"75958906-7f29-430b-b003-50b42a1f9d63","version":"5.2"}
# znajdzka {}
# znajdzka {"cellId":"vscode-notebook-cell:/c%3A/Users/aleks/Documents/programowanie/Python/AI/budget_manager/src/tracker/predict/work_file.ipynb#W3sZmlsZQ%3D%3D"}
# znajdzka {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":false,"code":"df = df.drop(['Mieszkanie','Zakupy','Rekreacja','wyjścia'], axis=1)"}

# %%
df
# Out:
#     Miesiąc  Wypłata  Dodatkowe  Mieszkanie  wynajem  Internet  bilety  \
# 0         1  3864.00     220.00           0      500     25.00    0.00
# 1         2  3680.00       0.00           0      500     25.00   28.27
# 2         3  3519.00     500.00           0      500     25.00  109.20
# 3         4  2967.00     800.00           0      500     25.00  109.20
# 4         5  2944.00       0.00           0      500     25.00   27.90
# 5         6  2944.00       0.00           0      500     25.00  215.39
# 6         7  3948.00    1200.00           0     1300      0.00  430.00
# 7         8  3948.00       0.00           0     1300      0.00    0.00
# 8         9  4194.95    1570.48           0     1300     77.33    0.00
# 9        10  5496.67       0.00           0     1300     99.00  191.98
# 10       11  5496.67     200.00           0     1300     99.00  455.50
# 11       12  5496.67    1915.22           0     1300     99.00   28.40
#
# ...

# %%
df = df.drop(['Mieszkanie','Zakupy','Rekreacja','wyjścia'], axis=1)
# Out:
# znajdzka {"date":"2025-08-02T09:38:51.021Z","msg_id":"ef23b509-87e4-45a9-be4e-56779928f673","msg_type":"execute_request","session":"66273808-415b-458f-95e8-652902888b3d","username":"75958906-7f29-430b-b003-50b42a1f9d63","version":"5.2"}
# znajdzka {}
# znajdzka {"cellId":"vscode-notebook-cell:/c%3A/Users/aleks/Documents/programowanie/Python/AI/budget_manager/src/tracker/predict/work_file.ipynb#X10sZmlsZQ%3D%3D"}
# znajdzka {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":false,"code":"for data in df:\n    temp_mean = df[data].mean()\n    df[data] = df[data].replace(0, temp_mean)"}

# %% [markdown]
# mean_value = gfg['G2'].mean()
#
# # Replace NaNs in column S2 with the
# # mean of values in the same column
# gfg['G2'].fillna(value=mean_value, inplace=True)

# %% [markdown]
# df['Value'] = df['Value'].replace(0, pd.NA).ffill()
# print(df)

# %%
for data in df:
    temp_mean = df[data].mean()
    df[data] = df[data].replace(0, temp_mean)
# Out:
# znajdzka {"date":"2025-08-02T09:38:52.996Z","msg_id":"074ca701-688a-478c-9c14-be93932a2ca9","msg_type":"execute_request","session":"66273808-415b-458f-95e8-652902888b3d","username":"75958906-7f29-430b-b003-50b42a1f9d63","version":"5.2"}
# znajdzka {}
# znajdzka {"cellId":"vscode-notebook-cell:/c%3A/Users/aleks/Documents/programowanie/Python/AI/budget_manager/src/tracker/predict/work_file.ipynb#X11sZmlsZQ%3D%3D"}
# znajdzka {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":false,"code":"df"}

# %%
df
# Out:
#     Miesiąc  Wypłata    Dodatkowe  wynajem   Internet      bilety  Telefon  \
# 0         1  3864.00   220.000000      500  25.000000  132.986667    14.41
# 1         2  3680.00   533.808333      500  25.000000   28.270000    14.41
# 2         3  3519.00   500.000000      500  25.000000  109.200000    14.41
# 3         4  2967.00   800.000000      500  25.000000  109.200000    14.41
# 4         5  2944.00   533.808333      500  25.000000   27.900000    14.41
# 5         6  2944.00   533.808333      500  25.000000  215.390000    14.41
# 6         7  3948.00  1200.000000     1300  43.694167  430.000000    14.41
# 7         8  3948.00   533.808333     1300  43.694167  132.986667   172.92
# 8         9  4194.95  1570.480000     1300  77.330000  132.986667    14.41
# 9        10  5496.67   533.808333     1300  99.000000  191.980000    14.41
# 10       11  5496.67   200.000000     1300  99.000000  455.500000    14.41
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# znajdzka {
#   "_version": 330,
#   "_FontManager__default_weight": "normal",
#   "default_size": null,
#   "defaultFamily": {
#     "ttf": "DejaVu Sans",
#     "afm": "Helvetica"
#   },
#   "afmlist": [
#     {
#       "fname": "fonts\\pdfcorefonts\\Times-Italic.afm",
#       "name": "Times",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\pcrro8a.afm",
#       "name": "Courier",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\pcrb8a.afm",
#       "name": "Courier",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "bold",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
# ...

# %%
from sklearn.model_selection import train_test_split

X = df.drop(['Suma'], axis=1)
y = df['Suma']
# Out:
# znajdzka {"date":"2025-08-02T09:40:52.745Z","msg_id":"95381954-40ed-48c2-b01f-c2e338d0c46c","msg_type":"execute_request","session":"66273808-415b-458f-95e8-652902888b3d","username":"75958906-7f29-430b-b003-50b42a1f9d63","version":"5.2"}
# znajdzka {}
# znajdzka {"cellId":"vscode-notebook-cell:/c%3A/Users/aleks/Documents/programowanie/Python/AI/budget_manager/src/tracker/predict/work_file.ipynb#X15sZmlsZQ%3D%3D"}
# znajdzka {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":false,"code":"y"}

# %%
y
# Out:
# 0     2688.45
# 1     2939.76
# 2     2998.35
# 3     2838.36
# 4      535.68
# 5      143.51
# 6     1332.93
# 7      166.84
# 8     2434.47
# 9     1232.20
# 10     770.22
# 11    3397.27
# Name: Suma, dtype: float64
# znajdzka {"date":"2025-08-02T09:40:58.633Z","msg_id":"2120c730-da74-4644-88ce-c23ecc8e3046","msg_type":"execute_request","session":"66273808-415b-458f-95e8-652902888b3d","username":"75958906-7f29-430b-b003-50b42a1f9d63","version":"5.2"}
# znajdzka {}
# znajdzka {}
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
# Out:
# znajdzka {"date":"2025-08-02T09:41:34.174Z","msg_id":"fa9d2123-562e-4564-9491-0a0a33a498ce","msg_type":"execute_request","session":"66273808-415b-458f-95e8-652902888b3d","username":"75958906-7f29-430b-b003-50b42a1f9d63","version":"5.2"}
# znajdzka {}
# znajdzka {}
# ...

# %%
train_data = X_train.join(y_train)
# Out:
# znajdzka {"date":"2025-08-02T09:41:50.305Z","msg_id":"58527a15-af91-4f35-948d-d4c3480b7a9d","msg_type":"execute_request","session":"66273808-415b-458f-95e8-652902888b3d","username":"75958906-7f29-430b-b003-50b42a1f9d63","version":"5.2"}
# znajdzka {}
# znajdzka {}
# ...

# %%
train_data
# Out:
#     Miesiąc  Wypłata    Dodatkowe  wynajem   Internet      bilety  Telefon  \
# 7         8  3948.00   533.808333     1300  43.694167  132.986667   172.92
# 1         2  3680.00   533.808333      500  25.000000   28.270000    14.41
# 4         5  2944.00   533.808333      500  25.000000   27.900000    14.41
# 6         7  3948.00  1200.000000     1300  43.694167  430.000000    14.41
# 10       11  5496.67   200.000000     1300  99.000000  455.500000    14.41
# 8         9  4194.95  1570.480000     1300  77.330000  132.986667    14.41
# 5         6  2944.00   533.808333      500  25.000000  215.390000    14.41
# 9        10  5496.67   533.808333     1300  99.000000  191.980000    14.41
# 3         4  2967.00   800.000000      500  25.000000  109.200000    14.41
# 2         3  3519.00   500.000000      500  25.000000  109.200000    14.41
#
#      czynsz    prąd  jedzenie i  chemia  ...  teren   fast-food  Ciuchy  \
# ...

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'Miesiąc'}>,
#         <Axes: title={'center': 'Wypłata'}>,
#         <Axes: title={'center': 'Dodatkowe'}>,
#         <Axes: title={'center': 'wynajem'}>,
#         <Axes: title={'center': 'Internet'}>],
#        [<Axes: title={'center': 'bilety'}>,
#         <Axes: title={'center': 'Telefon'}>,
#         <Axes: title={'center': 'czynsz'}>,
#         <Axes: title={'center': 'prąd'}>,
#         <Axes: title={'center': 'jedzenie i  chemia'}>],
#        [<Axes: title={'center': 'netflix, player, itp'}>,
#         <Axes: title={'center': 'spotify'}>,
#         <Axes: title={'center': 'teren'}>,
#         <Axes: title={'center': 'fast-food'}>,
#         <Axes: title={'center': 'Ciuchy'}>],
#        [<Axes: title={'center': 'kosmetyki'}>,
#         <Axes: title={'center': 'dodatkowe'}>,
#         <Axes: title={'center': 'niezaplanowane'}>,
#         <Axes: title={'center': 'stołówka'}>,
#         <Axes: title={'center': 'konto oszczędnościowe'}>],
# ...

# %%
import seaborn as sns
# Out:
# znajdzka {"date":"2025-08-02T09:43:01.667Z","msg_id":"a6ba1d51-100f-4258-9fcb-b649f73c706f","msg_type":"execute_request","session":"66273808-415b-458f-95e8-652902888b3d","username":"75958906-7f29-430b-b003-50b42a1f9d63","version":"5.2"}
# znajdzka {}
# znajdzka {}
# ...

# %%
sns.heatmap(train_data.corr())
# Out:
# <Axes: >
# znajdzka {"date":"2025-08-02T09:44:29.139Z","msg_id":"b47b18b8-c14c-4508-ad41-5a9829d537ea","msg_type":"execute_request","session":"66273808-415b-458f-95e8-652902888b3d","username":"75958906-7f29-430b-b003-50b42a1f9d63","version":"5.2"}
# znajdzka {}
# znajdzka {}
# ...

# %%
from sklearn.linear_model import LinearRegression

X_train, y_train = train_data.drop(['Suma'], axis=1), train_data['Suma']
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()
# znajdzka {"date":"2025-08-02T09:45:07.752Z","msg_id":"a8a55a40-1219-4a23-a711-64eb8229050b","msg_type":"execute_request","session":"66273808-415b-458f-95e8-652902888b3d","username":"75958906-7f29-430b-b003-50b42a1f9d63","version":"5.2"}
# znajdzka {}
# znajdzka {}
# ...

# %%
X_test.loc[[0]]
# Out:
#    Miesiąc  Wypłata  Dodatkowe  wynajem  Internet      bilety  Telefon  \
# 0        1   3864.0      220.0      500      25.0  132.986667    14.41
#
#     czynsz   prąd  jedzenie i  chemia  ...  spotify  teren  fast-food  Ciuchy  \
# 0  280.675  15.28          333.760833  ...     9.99  150.0      149.0  193.41
#
#     kosmetyki  dodatkowe  niezaplanowane  stołówka  konto oszczędnościowe  \
# 0  126.103333     234.22          104.93       121              66.666667
#
#    konie
# 0     50
#
# [1 rows x 21 columns]
# znajdzka {"date":"2025-08-02T09:49:02.192Z","msg_id":"0d30d5fb-6fc4-46d9-acd5-48aa9cbec6b4","msg_type":"execute_request","session":"66273808-415b-458f-95e8-652902888b3d","username":"75958906-7f29-430b-b003-50b42a1f9d63","version":"5.2"}
# znajdzka {}
# znajdzka {}
# ...

# %%
reg.predict(X_test.loc[[0]])
# Out:
# array([2704.90120331])

# %%
import pickle
from pathlib import Path
data = "blablabla"
model_name = "cos tam.sav"
model_path = 'C:/Users/aleks/Documents/programowanie/Python/AI/budget_manager/src/tracker/models/' + model_name
model_path_2 =Path('C:/Users/aleks/Documents/programowanie/Python/AI/budget_manager/src/tracker/models/model-2025-08-08T22:14:17.sav').as_posix() 
with open(model_path_2, 'wb') as file:
    pickle.dump(data, file)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[10], line 7
#       5 model_path = 'C:/Users/aleks/Documents/programowanie/Python/AI/budget_manager/src/tracker/models/' + model_name
#       6 model_path_2 =Path('C:/Users/aleks/Documents/programowanie/Python/AI/budget_manager/src/tracker/models/model-2025-08-08T22:14:17.sav').as_posix()
# ----> 7 with open(model_path_2, 'wb') as file:
#       8     pickle.dump(data, file)
#
# File c:\Users\aleks\anaconda3\envs\budget-manager\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# ...
